# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\My Drive\heart.csv") 
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,0:-1],df.iloc[:,-1],test_size=0.2,random_state=2)

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 172   56    1   1       120   240    0        1      169      0      0.0
# 128   52    1   2       138   223    0        1      169      0      0.0
# 363   53    1   2       130   246    1        0      173      0      0.0
# 636   59    0   0       174   249    0        1      143      1      0.0
# 798   59    1   3       170   288    0        0      159      0      0.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 299   52    1   1       120   325    0        1      172      0      0.2
# 534   54    0   2       108   267    0        0      167      0      0.0
# 584   55    1   0       132   353    0        1      132      1      1.2
# 493   55    1   0       132   353    0        1      132      1      1.2
# 527   62    0   0       124   209    0        1      163      0      0.0
#
#      slope  ca  thal
# 172      0   0     2
# 128      2   4     2
# 363      2   3     2
# ...

# %%
x_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 546   70    1   0       130   322    0        0      109      0      2.4
# 980   57    1   0       140   192    0        1      148      0      0.4
# 908   62    1   0       120   267    0        1       99      1      1.8
# 577   70    1   0       130   322    0        0      109      0      2.4
# 846   35    0   0       138   183    0        1      182      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 922   44    1   1       120   263    0        1      173      0      0.0
# 832   68    1   2       118   277    0        1      151      0      1.0
# 451   49    0   1       134   271    0        1      162      0      0.0
# 775   51    1   2       100   222    0        1      143      1      1.2
# 926   54    1   0       110   206    0        0      108      1      0.0
#
#      slope  ca  thal
# 546      1   3     2
# 980      1   0     1
# 908      1   2     3
# ...

# %%
y_train
# Out:
# 172    1
# 128    1
# 363    1
# 636    0
# 798    0
#       ..
# 299    1
# 534    1
# 584    0
# 493    0
# 527    1
# Name: target, Length: 820, dtype: int64

# %%
y_test
# Out:
# 546    0
# 980    1
# 908    0
# 577    0
# 846    1
#       ..
# 922    1
# 832    1
# 451    1
# 775    1
# 926    0
# Name: target, Length: 205, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
clf1 = LogisticRegression()
clf2 = DecisionTreeClassifier()

# %%
clf1.fit(x_train,y_train)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=clf1.predict(x_test)
y_pred2=clf2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,precision_score,f1_score

# %%
print('Accuracy Score:')
print("LogisticRegression: ",accuracy_score(y_test,y_pred1))
print("DecisionTreeClassification: ",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy Score:
# LogisticRegression:  0.848780487804878
# DecisionTreeClassification:  0.9804878048780488

# %%
print('Confusion Matrix:')
print("LogisticRegression:\n",confusion_matrix(y_test,y_pred1))
print("DecisionTreeClassification:\n",confusion_matrix(y_test,y_pred2))
# Out:
# Confusion Matrix:
# LogisticRegression:
#  [[82 23]
#  [ 8 92]]
# DecisionTreeClassification:
#  [[101   4]
#  [  0 100]]

# %%
print('F1 Score:')
print("LogisticRegression: ",f1_score(y_test,y_pred1))
print("DecisionTreeClassification: ",f1_score(y_test,y_pred2))
# Out:
# F1 Score:
# LogisticRegression:  0.8558139534883721
# DecisionTreeClassification:  0.9803921568627451

# %%
print('Recall Score:')
print("LogisticRegression: ",recall_score(y_test,y_pred1))
print("DecisionTreeClassification: ",recall_score(y_test,y_pred2))
# Out:
# Recall Score:
# LogisticRegression:  0.92
# DecisionTreeClassification:  1.0

# %%
print('Recall Score:')
print("LogisticRegression: ",recall_score(y_test,y_pred1,average=None))
print("DecisionTreeClassification: ",recall_score(y_test,y_pred2,average=None))
# Out:
# Recall Score:
# LogisticRegression:  [0.78095238 0.92      ]
# DecisionTreeClassification:  [0.96190476 1.        ]

# %%
print('Precision Score:')
print("LogisticRegression: ",precision_score(y_test,y_pred1))
print("DecisionTreeClassification: ",precision_score(y_test,y_pred2))
# Out:
# Precision Score:
# LogisticRegression:  0.8
# DecisionTreeClassification:  0.9615384615384616

# %%
print('Precision Score:')
print("LogisticRegression: ",precision_score(y_test,y_pred1,average=None))
print("DecisionTreeClassification: ",precision_score(y_test,y_pred2,average=None))
# Out:
# Precision Score:
# LogisticRegression:  [0.91111111 0.8       ]
# DecisionTreeClassification:  [1.         0.96153846]

# %%
from sklearn.metrics import classification_report

# %%
print("For LR Model:")
print(classification_report(y_test,y_pred1)) 
print("\nFor DT Model:")
print(classification_report(y_test,y_pred2))
# Out:
# For LR Model:
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       105
#            1       0.80      0.92      0.86       100
#
#     accuracy                           0.85       205
#    macro avg       0.86      0.85      0.85       205
# weighted avg       0.86      0.85      0.85       205
#
#
# For DT Model:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       105
#            1       0.96      1.00      0.98       100
#
#     accuracy                           0.98       205
#    macro avg       0.98      0.98      0.98       205
# weighted avg       0.98      0.98      0.98       205
