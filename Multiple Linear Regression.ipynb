# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\My Drive\creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
X = df.drop(columns='Class')
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y = df['Class'] 
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from sklearn.preprocessing import RobustScaler
sc = RobustScaler()
X[['Time','Amount']] = sc.fit_transform(X[['Time','Amount']] )
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0      -0.994983  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1      -0.994983   1.191857   0.266151  0.166480  0.448154  0.060018
# 2      -0.994972  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3      -0.994972  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4      -0.994960  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  1.034951 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  1.034963  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  1.034975   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  1.034975  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  1.035022  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=102)

# %%
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 249966  0.821967 -0.840412 -0.269100 -0.732559 -1.228956 -0.186723  0.238405
# 168833  0.407829 -0.362793  0.399138 -0.029062 -0.414191  0.561203 -1.204172
# 134364 -0.046065  1.534655 -0.800318 -0.041495 -1.254067 -1.316018 -1.546395
# 216391  0.655118 -3.983365  4.217823 -2.387621 -2.612066  1.392347 -0.849011
# 83296  -0.292708 -0.361706  1.074935  1.278501  0.073549 -0.009754 -0.989990
# ...          ...       ...       ...       ...       ...       ...       ...
# 17353  -0.658419 -0.482400  0.946538  1.059029  1.864402 -0.597429  0.497269
# 69611  -0.366440  1.270844  0.180515 -0.065530  0.241853  0.140340 -0.271139
# 117570 -0.117095 -2.526794 -0.343770  0.201527 -0.966384 -1.271303 -0.503000
# 111471 -0.146289 -0.469045  0.959807  1.452109  0.188666  0.442888  0.133357
# 108800 -0.159941  1.457301 -0.173040 -0.165354 -0.675050 -0.501551 -1.365176
#
# ...

# %%
y_train
# Out:
# 249966    0
# 168833    0
# 134364    0
# 216391    0
# 83296     0
#          ..
# 17353     0
# 69611     0
# 117570    0
# 111471    0
# 108800    0
# Name: Class, Length: 199364, dtype: int64

# %%
X_test
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 183615  0.483864 -0.870697 -0.059587  1.006790 -2.503786  0.709094 -0.543474
# 205350  0.599279  1.368475 -1.343660 -1.977593  0.404269 -0.163068 -0.711084
# 217361  0.659888 -0.273100  0.867481 -1.819350 -1.530409  2.897867  3.250083
# 82501  -0.296808 -0.500222  0.373726  1.406805  0.096259  0.794839  1.470979
# 71124  -0.358604 -1.036570  1.689033  1.769131  2.698428 -0.600468  0.501110
# ...          ...       ...       ...       ...       ...       ...       ...
# 254160  0.844853 -0.703380  1.037510 -1.005636 -0.559053  1.013633 -0.961705
# 93026  -0.240510  1.082927 -0.052513  1.228710  1.103870 -0.657513  0.522452
# 205206  0.598468  1.785169 -0.977434 -2.307540 -0.212162 -0.255255 -1.759956
# 140875 -0.008165  1.130104 -0.641208  0.712893 -0.088963 -0.641806  0.898885
# 242853  0.787063 -0.571509  1.838561  1.796577  3.964657  0.880896  0.946423
#
# ...

# %%
y_test
# Out:
# 183615    0
# 205350    0
# 217361    0
# 82501     0
# 71124     0
#          ..
# 254160    0
# 93026     0
# 205206    0
# 140875    0
# 242853    0
# Name: Class, Length: 85443, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model = lr.fit(X_train,y_train)
model
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([-0.00013177, -0.00037183, -0.00226212, ...,  0.00060668,
#        -0.00064795,  0.00270641])

# %%
train_acc = lr.predict(X_train)
train_acc
# Out:
# array([-7.47212632e-04,  8.62182723e-03, -9.94805644e-05, ...,
#        -3.80585816e-03,  2.85046283e-03, -8.44502767e-04])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5351592247195285

# %%
r2_score(y_train,train_acc)
# Out:
# 0.5151398965312519

# %%
print(sc.transform([[2,2.69]]))
# Out:
# [[-0.99496    -0.26982463]]
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(

# %%
lr.predict([[-0.56456,0.4336,0.354785,-0.34656,1.54654,0.34925,-1.34436,0.34952,1.34234,0.436065,-0.564654,1.546986,1.3255,0.78087,
0.14324,1.9999,-1.4398736,0.3545,1.34656,0.54654,-1.3425,0.348436,1.3452,0.34234,1.43665,1.564654,0.5466,-0.3255,1.78087,1.14324]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.00893363])
