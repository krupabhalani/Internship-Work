# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
X = df.drop(columns='charges')
y = df['charges']

# %%
X
# Out:
#       age     sex     bmi  children smoker     region
# 0      19  female  27.900         0    yes  southwest
# 1      18    male  33.770         1     no  southeast
# 2      28    male  33.000         3     no  southeast
# 3      33    male  22.705         0     no  northwest
# 4      32    male  28.880         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 1333   50    male  30.970         3     no  northwest
# 1334   18  female  31.920         0     no  northeast
# 1335   18  female  36.850         0     no  southeast
# 1336   21  female  25.800         0     no  southwest
# 1337   61  female  29.070         0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
X = pd.get_dummies(X,columns=['sex','region'],drop_first=True)

# %%
X['smoker'] = X['smoker'].map({'yes':1,'no':0})

# %%
X
# Out:
#       age     bmi  children  smoker  sex_male  region_northwest  \
# 0      19  27.900         0       1         0                 0
# 1      18  33.770         1       0         1                 0
# 2      28  33.000         3       0         1                 0
# 3      33  22.705         0       0         1                 1
# 4      32  28.880         0       0         1                 1
# ...   ...     ...       ...     ...       ...               ...
# 1333   50  30.970         3       0         1                 1
# 1334   18  31.920         0       0         0                 0
# 1335   18  36.850         0       0         0                 0
# 1336   21  25.800         0       0         0                 0
# 1337   61  29.070         0       1         0                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 8 columns]

# %%
from sklearn.preprocessing import RobustScaler
sc = RobustScaler()
X[['age','bmi']] = sc.fit_transform(X[['age','bmi']])
X.head()
# Out:
#         age       bmi  children  smoker  sex_male  region_northwest  \
# 0 -0.833333 -0.297708         0       1         0                 0
# 1 -0.875000  0.401310         1       0         1                 0
# 2 -0.458333  0.309616         3       0         1                 0
# 3 -0.250000 -0.916344         0       0         1                 1
# 4 -0.291667 -0.181006         0       0         1                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#            age       bmi  children  smoker  sex_male  region_northwest  \
# 621  -0.083333  0.440607         4       1         1                 0
# 194  -0.875000  0.479905         0       0         1                 0
# 240  -0.666667  0.746651         2       1         0                 0
# 1168 -0.291667  0.571599         2       0         1                 0
# 1192  0.791667  0.237571         1       0         0                 0
#
#       region_southeast  region_southwest
# 621                  0                 1
# 194                  1                 0
# 240                  0                 0
# 1168                 0                 1
# 1192                 0                 0

# %%
X_test
# Out:
#            age       bmi  children  smoker  sex_male  region_northwest  \
# 578   0.541667 -0.023817         1       0         1                 0
# 610   0.333333 -0.122656         1       0         0                 0
# 569   0.375000  1.210479         2       1         1                 1
# 1034  0.916667  0.950283         0       0         1                 1
# 198   0.500000 -1.470676         0       0         0                 1
# ...        ...       ...       ...     ...       ...               ...
# 1084  0.958333  0.011313         2       0         0                 1
# 726   0.083333 -0.237571         1       0         1                 1
# 1132  0.750000  1.176541         0       0         1                 0
#         2179.78250416, 11765.29613638,  8959.02208536, 43083.92638417,
#        11756.13662848,  3767.42762895,  4808.90045416,  8296.8374516 ,
#         5136.66446534,  3795.90105465, 13302.06389052, 13204.70244339,
#         7687.22054365, 14814.71155459, 12448.53796126, 10693.13585073,
#         5414.81323133,  7836.98003059, 15379.63982119, 10228.03046287,
#         6196.0690564 ,  1447.40436342,  7138.46212083,  6512.43025812,
#        10603.51599753,  3588.11003935,  4697.97981058,  5583.95079728,
#         5683.98239485,  6966.4593677 , 37350.12057759,  3220.08546813,
#        13354.56351579,  9844.46619913, 13404.03978415,  4467.4633472 ,
#         6733.3719449 , 32275.91813326,  4164.42270566,  3845.32744633,
#        14889.32603643, 13456.37857774, 36205.55650914,  5940.89796132,
#         6826.21692111, 24851.6975201 ,  4665.40858626,  3187.90013441,
#         8651.64317341, 10930.65074471,  5681.74322891,  6456.70304718,
#        13596.95347628, 44657.27325312, 14457.83620418, 22241.95029945,
#         7390.1635014 , 42096.54026587,  5716.62962223, 11567.69547561,
#         7375.19469502,  1087.25252928, 11353.59838574, 14781.87184276,
#         7783.46427929,  3082.06390384,  7874.90221619,  3059.5861446 ,
#         8763.70929958,  7185.43121447, 15722.51139933,  7799.04017352,
#         7122.39594328, 10590.42611484,  9498.78187693,  4933.06818191,
#        12931.17959852, 16365.03492511, 13622.45590523, 12873.40405004,
#         8010.95281539,  4460.5290336 ,  3148.1556522 , 10466.9900627 ,
#        13087.53068804,  9470.80966833,  6377.43785963,  8205.19470051,
#        11350.2147818 , 29070.43624827,  7790.1933187 , 13286.58411925,
#         6592.78662909, 36356.48094963,  8524.07380667,  8408.5456839 ,
#        11315.46337876, 12868.52570618,  5313.52565775,  9589.78731003,
#         4545.45699453,  7817.52833783, 26307.86376952, 43790.97265789,
#         5154.50625574,  3203.73054821,  4793.31763579,  2762.73659743,
#         9089.56540699,  2054.38963383,  7158.09088259,  5387.26001425,
#         9878.4975172 , 31948.63968515, 40649.06030994, 16688.91689582,
#         8806.56057881, 12769.12105781, 41300.16466558, 10661.98556025])

# %%
train_acc = lr.predict(X_train_poly)
train_acc
# Out:
# array([35443.76273806,  2732.99961518, 40672.92213182, ...,
#         7947.29590437,  3699.26687668,  5404.07755322])

# %% [markdown]
# # evaluation

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8802620539610428

# %%
r2_score(y_train,train_acc)
# Out:
# 0.8373709632701476

# %% [markdown]
# # real data prediction

# %%
sc.transform([[19,27.900]])
# Out:
# C:\Users\Helly\Downloads\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(
# array([[-0.83333333, -0.29770765]])

# %%
lr.predict(poly.transform([[-0.833333, -0.297708, 0, 1, 0, 0, 0, 1]]))
# Out:
# C:\Users\Helly\Downloads\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([24521.55059636])

# %% [markdown]
# # for loop

# %%
for var in range(1,5):
    poly = PolynomialFeatures(degree=var)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)
    lr = LinearRegression()
    model = lr.fit(X_train_poly,y_train)
    y_pred = lr.predict(X_test_poly)
    print(r2_score(y_test,y_pred))
# Out:
# 0.7999876970680435
# 0.8802620539610428
# 0.8751791257987495
# 0.850765714634891
